# %%
import matplotlib.pyplot as plt
import pandas as pd

DATA_FILE_NAME = "ProcessedData.csv"
df = pd.read_csv(DATA_FILE_NAME)
data_size=len(df)
df
# Out:
#            OutcomeType AnimalType            Sex  WeeksOldUponOutcome  \
# 0      Return_to_owner        Dog  Neutered Male                 52.0
# 1           Euthanasia        Cat  Spayed Female                 52.0
# 2             Adoption        Dog  Neutered Male                104.0
# 3             Transfer        Cat    Intact Male                  3.0
# 4             Transfer        Dog  Neutered Male                104.0
# 5             Transfer        Dog  Intact Female                  4.0
# 6             Transfer        Cat    Intact Male                  3.0
# 7             Transfer        Cat        Unknown                  3.0
# 8             Adoption        Dog  Spayed Female                 20.0
# 9             Adoption        Dog  Spayed Female                 52.0
# 10            Transfer        Cat        Unknown                104.0
# 11            Adoption        Dog  Spayed Female                104.0
# 12            Adoption        Dog  Neutered Male                208.0
# 13     Return_to_owner        Dog  Neutered Male                104.0
# 14     Return_to_owner        Dog  Neutered Male                 52.0
# 15            Adoption        Cat  Neutered Male                 12.0
# 16            Transfer        Cat    Intact Male                  3.0
# 17            Transfer        Dog  Intact Female                  2.0
# 18            Transfer        Cat  Intact Female                104.0
# 19     Return_to_owner        Dog  Neutered Male                 52.0
# 20            Transfer        Dog    Intact Male                  8.0
# 21            Transfer        Cat  Spayed Female                 52.0
# 22            Adoption        Dog  Spayed Female                104.0
# 23            Adoption        Dog  Neutered Male                 40.0
# 24     Return_to_owner        Dog  Neutered Male                  8.0
# 25            Transfer        Cat  Intact Female                  4.0
# 26            Adoption        Dog  Spayed Female                 24.0
# 27            Adoption        Dog  Spayed Female                260.0
# 28            Adoption        Cat  Spayed Female                  8.0
# 29     Return_to_owner        Cat  Neutered Male                364.0
# ...                ...        ...            ...                  ...
# 26699       Euthanasia        Dog  Neutered Male                104.0
# 26700  Return_to_owner        Dog    Intact Male                 40.0
# 26701         Transfer        Dog  Intact Female                 44.0
# 26702             Died        Cat  Spayed Female                104.0
# 26703         Transfer        Cat  Neutered Male                312.0
# 26704         Transfer        Cat  Intact Female                  4.0
# 26705         Transfer        Cat  Intact Female                  8.0
# 26706         Adoption        Cat  Spayed Female                  8.0
# 26707       Euthanasia        Cat        Unknown                 52.0
# 26708         Transfer        Dog  Neutered Male                104.0
# 26709         Adoption        Dog  Spayed Female                  4.0
# 26710         Transfer        Dog  Intact Female                  4.0
# 26711         Transfer        Dog  Intact Female                 52.0
# 26712  Return_to_owner        Dog  Neutered Male                624.0
# 26713       Euthanasia        Cat  Intact Female                936.0
# 26714         Adoption        Cat  Spayed Female                  8.0
# 26715         Adoption        Dog  Spayed Female                  8.0
# 26716         Adoption        Dog  Neutered Male                  8.0
# 26717  Return_to_owner        Dog  Spayed Female                468.0
# 26718         Adoption        Dog  Neutered Male                  8.0
# 26719         Transfer        Cat        Unknown                104.0
# 26720         Adoption        Cat  Spayed Female                  8.0
# 26721         Adoption        Cat  Spayed Female                260.0
# 26722         Transfer        Cat    Intact Male                 20.0
# 26723         Adoption        Dog  Neutered Male                312.0
# 26724         Transfer        Cat    Intact Male                  4.0
# 26725         Transfer        Cat  Spayed Female                 12.0
# 26726         Adoption        Dog  Neutered Male                208.0
# 26727         Transfer        Cat    Intact Male                  4.0
# 26728         Transfer        Cat    Intact Male                 52.0
#
#        isPurebred                             Breed 1  \
# 0               0               Shetland Sheepdog Mix
# 1               0              Domestic Shorthair Mix
# 2               0                        Pit Bull Mix
# 3               0              Domestic Shorthair Mix
# 4               0                          Lhasa Apso
# 5               0                       Cairn Terrier
# ...                                   ...            ...           ...
# 26699       American Pit Bull Terrier Mix          Black         White
# 26700                      Great Pyrenees          Cream           Tan
# 26701            Jack Russell Terrier Mix          Black         White
# 26702                         Siamese Mix     Lynx Point    Lynx Point
# 26703               Domestic Longhair Mix     Seal Point    Seal Point
# 26704              Domestic Shorthair Mix          Black         White
# 26705              Domestic Shorthair Mix         Tortie        Tortie
# 26706              Domestic Shorthair Mix          Black         Black
# 26707              Domestic Shorthair Mix    Brown Tabby   Brown Tabby
# 26708             Chihuahua Shorthair Mix          Brown         White
# 26709             Chihuahua Shorthair Mix           Buff         Sable
# 26710                   Yorkshire Terrier          Black         Brown
# 26711                           Dachshund           Buff          Buff
# 26712                         Rat Terrier      Chocolate           Tan
# 26713               Domestic Longhair Mix         Tortie        Tortie
# 26714              Domestic Shorthair Mix   Orange Tabby  Orange Tabby
# 26715                         Pointer Mix          Black         White
# 26716                    Newfoundland Mix          Black         White
# 26717                     Bullmastiff Mix          Black         Black
# 26718                      Siberian Husky          Black      Tricolor
# 26719              Domestic Shorthair Mix    Brown Tabby         White
# 26720              Domestic Shorthair Mix    Brown Tabby   Brown Tabby
# 26721              Domestic Shorthair Mix          Black         Black
# 26722              Domestic Shorthair Mix   Orange Tabby  Orange Tabby
# 26723                   Staffordshire Mix           Blue         White
# 26724              Domestic Shorthair Mix    Brown Tabby         White
# 26725              Domestic Shorthair Mix    Brown Tabby   Brown Tabby
# 26726             Old English Bulldog Mix            Tan         White
# 26727              Domestic Shorthair Mix          Black         Black
# 26728              Domestic Shorthair Mix    Brown Tabby         White
#
# [26729 rows x 9 columns]

# %%
outcome_types=df.groupby("OutcomeType")
for outcome in outcome_types.groups.keys():
    size=len(outcome_types.groups[outcome])
    print(outcome,size,round(size/data_size,2))
outcomePlot = outcome_types['OutcomeType'].count().plot.bar(title = "Outcomes of Shelter Animals")
plt.savefig('Animal_Outcome_Counts.png',bbox_inches = "tight")
# Out:
# Adoption 10769 0.4
# Died 197 0.01
# Euthanasia 1555 0.06
# Return_to_owner 4786 0.18
# Transfer 9422 0.35

# %%
animalTypePlot = df.groupby("AnimalType")["AnimalType"].count().plot.bar(title = "Animal Types")
plt.savefig('Animal_Type_Counts.png',bbox_inches = "tight")

# %%
#color_types = df.groupby(['Color 1','Color 2'])['OutcomeType'].count().rename(columns={"OutcomeType":"Count"})
color_types = df.groupby(['Color 1','Color 2']).size()#.reset_index(name='counts')
data = pd.Series({'1': color_types[color_types == 1].count(),
        '2-10': color_types[(color_types >= 2) & (color_types <= 10)].count(),
        '11-100': color_types[(color_types >= 11) & (color_types <= 100)].count(),
        '101-1000': color_types[(color_types >= 101) & (color_types <= 1000)].count(),
        '1001-3005': color_types[(color_types > 1000)].count()
       })
data.plot.bar(title='Color combination counts')
plt.savefig('Color_Combo_Counts.png',bbox_inches = "tight")

# %%
breed_types = df.groupby(['Breed 1','Breed 2']).size()#.reset_index(name='counts')
data = pd.Series({'1': breed_types[breed_types == 1].count(),
        '2-10': breed_types[(breed_types >= 2) & (breed_types <= 10)].count(),
        '11-100': breed_types[(breed_types >= 11) & (breed_types <= 100)].count(),
        '101-1000': breed_types[(breed_types >= 101) & (breed_types <= 1000)].count(),
        '1001-3005': breed_types[(breed_types > 1000)].count()
       })
data.plot.bar(title='Breed combination counts')
plt.savefig('Breed_Combo_Counts.png',bbox_inches = "tight")

# %%
sex_types = df.groupby('Sex')['Sex'].count().plot.bar(title = "Sex Type Counts")
plt.savefig('Sex_Type_Counts.png',bbox_inches = "tight")
